# %%
#Menginstal library yang diperlukan
# !pip install pandas # Menginstal library pandas untuk manipulasi data
# !curl -sl https://deb.nodesource.com/setup_18.x | sudo -E bash - # Mengunduh dan menyiapkan repositori Node.js
# !sudo apt-get install -y nodejs # Menginstal Node.js untuk menjalankan perintah berbasis JavaScript
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# 2025-03-21 12:51:42 - Installing pre-requisites
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,003 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [3,962 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,535 kB]
# Get:14 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,237 kB]
# Get:15 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,692 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,677 kB]
# Get:17 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,762 kB]
# Fetched 24.3 MB in 6s (4,203 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ca-certificates is already the newest version (20240203~22.04.1).
# curl is already the newest version (7.81.0-1ubuntu1.20).
# gnupg is already the newest version (2.2.27-3ubuntu2.1).
# gnupg set to manually installed.
# The following NEW packages will be installed:
#   apt-transport-https
# 0 upgraded, 1 newly installed, 0 to remove and 30 not upgraded.
# Need to get 1,510 B of archives.
# After this operation, 170 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 apt-transport-https all 2.4.13 [1,510 B]
# Fetched 1,510 B in 0s (17.9 kB/s)
# Selecting previously unselected package apt-transport-https.
# (Reading database ... 126209 files and directories currently installed.)
# Preparing to unpack .../apt-transport-https_2.4.13_all.deb ...
# Unpacking apt-transport-https (2.4.13) ...
# Setting up apt-transport-https (2.4.13) ...
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Get:7 https://deb.nodesource.com/node_18.x nodistro InRelease [12.1 kB]
# Hit:8 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:11 https://deb.nodesource.com/node_18.x nodistro/main amd64 Packages [11.4 kB]
# Hit:12 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 23.5 kB in 2s (11.5 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# 2025-03-21 12:52:06 - Repository configured successfully.
# 2025-03-21 12:52:06 - To install Node.js, run: apt-get install nodejs -y
# 2025-03-21 12:52:06 - You can use N|solid Runtime as a node.js alternative
# 2025-03-21 12:52:06 - To install N|solid Runtime, run: apt-get install nsolid -y
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   nodejs
# 0 upgraded, 1 newly installed, 0 to remove and 30 not upgraded.
# Need to get 29.7 MB of archives.
# After this operation, 187 MB of additional disk space will be used.
# Get:1 https://deb.nodesource.com/node_18.x nodistro/main amd64 nodejs amd64 18.20.6-1nodesource1 [29.7 MB]
# Fetched 29.7 MB in 1s (54.6 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package nodejs.
# (Reading database ... 126213 files and directories currently installed.)
# Preparing to unpack .../nodejs_18.20.6-1nodesource1_amd64.deb ...
# Unpacking nodejs (18.20.6-1nodesource1) ...
# Setting up nodejs (18.20.6-1nodesource1) ...
# Processing triggers for man-db (2.10.2-1) ...

# %%
#Membuat file name
filename1='Naruto.csv' # Nama file untuk menyimpan data tweet Naruto
filename2='Sasuke.csv' # Nama file untuk menyimpan data tweet Sasuke
search_keyword1='Naruto until:2025-03-18 since:2025-03-08' # Kata kunci pencarian untuk Wibu dalam rentang waktu 8-18 Maret 2025
search_keyword2='Sasuke until:2025-03-18 since:2025-03-08' # Kata kunci pencarian untuk Kpopers dalam rentang waktu 8-18 Maret 2025
limit=200 # Batas maksimum jumlah tweet yang diambil untuk setiap pencarian (200 tweet)

# Menggunakan npx untuk menjalankan tweet-harvest dan menyimpan hasilnya ke file CSV
# !npx --yes tweet-harvest@latest -o {filename1} -s {search_keyword1} -l {limit} --token "148f44e07beff165788253423b80ed7d0d46f1ff" # Mengambil tweet berdasarkan kata kunci Naruto
# !npx --yes tweet-harvest@latest -o {filename2} -s {search_keyword2} -l {limit} --token "148f44e07beff165788253423b80ed7d0d46f1ff" # Mengambil tweet berdasarkan kata kunci Sasuke
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠋npm warn deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# ⠙npm warn deprecated glob@7.2.3: Glob versions prior to v9 are no longer supported
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1)
# Filling in keywords: Naruto
#
#  (2) (3)Created new directory: /content/tweets-data
#
#
# Your tweets saved to: /content/tweets-data/Naruto.csv
# Total tweets saved: 19
#
# -- Scrolling... (1) (2) (3) (4)
#
# Your tweets saved to: /content/tweets-data/Naruto.csv
# Total tweets saved: 39
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Naruto.csv
# Total tweets saved: 59
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Naruto.csv
# Total tweets saved: 79
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Naruto.csv
# Total tweets saved: 94
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Naruto.csv
# Total tweets saved: 104
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Naruto.csv
# Total tweets saved: 115
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Naruto.csv
# Total tweets saved: 135
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Naruto.csv
# Total tweets saved: 152
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Naruto.csv
# Total tweets saved: 169
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Naruto.csv
# Total tweets saved: 183
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/Naruto.csv
# Total tweets saved: 194
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Naruto.csv
# Total tweets saved: 214
#
# --Taking a break, waiting for 10 seconds...
# Got 214 tweets, done scrolling...
# ⠙⠙⠹⠸⠼⠴⠦⠧Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# Note: Keep your access token secret! Don't share it with anyone else.
# Note: This script only runs on your local device.
#
#
# Opening twitter search page...
#
#
# -- Scrolling... (1)
# Filling in keywords: Sasuke
#
#  (2)
#
# Your tweets saved to: /content/tweets-data/Sasuke.csv
# Total tweets saved: 19
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Sasuke.csv
# Total tweets saved: 39
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Sasuke.csv
# Total tweets saved: 59
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Sasuke.csv
# Total tweets saved: 79
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/Sasuke.csv
# Total tweets saved: 99
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Sasuke.csv
# Total tweets saved: 119
#
# --Taking a break, waiting for 10 seconds...
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Sasuke.csv
# Total tweets saved: 139
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/Sasuke.csv
# Total tweets saved: 159
#
# -- Scrolling... (1) (2)
#
# Your tweets saved to: /content/tweets-data/Sasuke.csv
# Total tweets saved: 174
#
# -- Scrolling... (1)
#
# Your tweets saved to: /content/tweets-data/Sasuke.csv
# Total tweets saved: 193
#
# -- Scrolling... (1) (2) (3)
#
# Your tweets saved to: /content/tweets-data/Sasuke.csv
# Total tweets saved: 206
# Got 206 tweets, done scrolling...
# ⠙

# %%
import pandas as pd

# Baca file pertama (Naruto)
file_path1 = "tweets-data/Naruto.csv" # Menentukan lokasi file CSV yang berisi data tweet bertema "Naruto"
df1 = pd.read_csv(file_path1, delimiter=",") # Membaca file CSV "Naruto" dan menyimpannya dalam DataFrame df1.
display(df1) # Menampilkan DataFrame Naruto

# Baca file kedua (Sasuke)
file_path2 = "tweets-data/Sasuke.csv" # Menentukan lokasi file CSV yang berisi data tweet bertema "Sasuke"
df2 = pd.read_csv(file_path2, delimiter=",") # Membaca file CSV "Sasuke" dan menyimpannya dalam DataFrame df2.
display(df2) # Menampilkan DataFrame Sasuke
# Out:
#      conversation_id_str                      created_at  favorite_count  \
# 0    1902057613014999394  Tue Mar 18 18:00:48 +0000 2025           38159
# 1    1902375911623643626  Wed Mar 19 15:05:36 +0000 2025           92581
# 2    1902918117145317540  Fri Mar 21 03:00:08 +0000 2025            1378
# 3    1902552907708559423  Thu Mar 20 03:02:32 +0000 2025              19
# 4    1902890342481055842  Fri Mar 21 01:09:46 +0000 2025             840
# ..                   ...                             ...             ...
# 209  1900799381365993648  Sat Mar 15 06:41:02 +0000 2025            3565
# 210  1900334259098780068  Thu Mar 13 23:52:48 +0000 2025           14224
# 211  1901018841242583097  Sat Mar 15 21:13:05 +0000 2025            1280
# 212  1900885310579540083  Sat Mar 15 12:22:29 +0000 2025            7694
# 213  1901047511814676868  Sat Mar 15 23:07:01 +0000 2025           13732
#
#                                              full_text               id_str  \
# 0                              https://t.co/S96DxM5qJp  1902057613014999394
# 1    Real Betis drop a special edition Naruto jerse...  1902375911623643626
# 2    2008年36号 第411話「八尾vsサスケ!!」 キラービーとの一騎打ちに挑むサスケ。高速...  1902918117145317540
# 3    やっぱりバイブレーションスターズのNARUTOシリーズはクオリティ高い‼️ https://...  1902556332206780753
# 4    【商品情報】 ／ #NARUTO 3Dレリーフスタンド （税込400円） ＼ 立体要素のある...  1902890342481055842
# ..                                                 ...                  ...
# 209        itachi &amp; Kisame https://t.co/uYL4Pj8PPF  1900799381365993648
# 210  Con 330 Millones de horas vistas NARUTO fue el...  1900334259098780068
# 211                    Susanoo https://t.co/jyViNQJSGm  1901018841242583097
# 212                         oc https://t.co/YHxxP3149P  1900885310579540083
# 213              Sasuke Uchiha https://t.co/iSplb8N2V6  1901047511814676868
#
#                                            image_url in_reply_to_screen_name  \
# 1            naruto to sasuke: https://t.co/yLXZwNTtLC  1902735919750230249
# 2             Sukuna vs Sasuke https://t.co/v2gseV8nHz  1902714073940439338
# 3    ᯓ Sasuke Being The Glue Of Team7 ⭑.ᐟ ── a shor...  1902087180539064570
# 4    Sakura from Sasuke Retsuden manga️ https://t.c...  1901843171509690585
# ..                                                 ...                  ...
# 201  just sasuke and sarada staring at sleeping sak...  1902185778152653215
# 202  Essa cena é tão fofinha a carinha dele que amo...  1902450080105254957
# 203  Mafia? Office?? Both themes are so good~ #sasu...  1901924020666175880
# 204  gente mas é ÓBVIO que as comidas na arte tão f...  1900608867303612891
# 205                            https://t.co/5ncckQ9H8c  1901468983162765397
#
#                                              image_url  \
# 0      https://pbs.twimg.com/media/GmSiTKeXMAAzZT_.jpg
# 1      https://pbs.twimg.com/media/GmfgOwCboAA9Xy6.jpg
# 2    https://pbs.twimg.com/ext_tw_video_thumb/19027...
# 3      https://pbs.twimg.com/media/GmWSNbeXwAAkYYh.jpg
# 4      https://pbs.twimg.com/media/GmS0STAacAAvDKS.jpg
# ..                                                 ...
# 201    https://pbs.twimg.com/media/GmXr4ZUWUAATPV9.jpg
# 202    https://pbs.twimg.com/media/GmbcRAUXQAAwVlf.jpg
# 203    https://pbs.twimg.com/media/GmT90G3XkAArIVH.jpg
# 204    https://pbs.twimg.com/media/GmBRsVeXYAEAk2L.jpg
# 205    https://pbs.twimg.com/media/GmNf9gVXMAAJi1M.jpg
#
#     in_reply_to_screen_name lang              location  quote_count  \
# 0                       NaN   en                   NaN            1
# 1                       NaN   tl     icon: @ns_ichiban           16
# 2                       NaN   tl                  呪術廻戦           35
# 3                       NaN   en  Blk ⭑ She ⭑ Her ⭑BTS           19
# 4                       NaN   no                   NaN            8
# ..                      ...  ...                   ...          ...
# 201                     NaN   tl                   NaN            0
# 202                     NaN   pt                   NaN            2
# 203                     NaN   en                   NaN            0
# 204                     NaN   pt                    🌸🍅            2
# 205                     NaN  zxx    sasuke love bot ☽             2
#
#      reply_count  retweet_count  \
# 0              0             87
# 1              3            528
# 2             36            380
# 3              3            357
# 4              0             91
# ..           ...            ...
# 201            0             59
# 202            4             67
# 203            4             77
# 204            5              8
# 205            0              6
#
#                                              tweet_url          user_id_str  \
# 0    https://x.com/nickiventi/status/19018233992083...  1567490983775830024
# 1     https://x.com/coegumi/status/1902735919750230249  1648252823623155713
# 2    https://x.com/AnimexTwts/status/19027140739404...   836533158669500416
# 3    https://x.com/Kuraphobic/status/19020871805390...  1512078984938340370
# 4    https://x.com/stansakurachan/status/1901843171...  1604618350713360387
# ..                                                 ...                  ...
# 201  https://x.com/nickiventi/status/19021857781526...  1567490983775830024
# 202  https://x.com/jujubsmi/status/1902450080105254957  1601930077025050625
# 203  https://x.com/laydi233/status/1901924020666175880   730192032208175105
# 204  https://x.com/fusoptimu/status/190060886730361...  1735417691844853760
# 205  https://x.com/hourlysasuke/status/190146898316...  1331432666047066113
#
#            username
# 0        nickiventi
# 1           coegumi
# 2        AnimexTwts
# 3        Kuraphobic
# 4    stansakurachan
# ..              ...
# 201      nickiventi
# 202        jujubsmi
# 203        laydi233
# 204       fusoptimu
# 205    hourlysasuke
#
# [206 rows x 15 columns]
